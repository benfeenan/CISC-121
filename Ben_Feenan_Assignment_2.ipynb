# %% [markdown]
# <a href="https://colab.research.google.com/github/benfeenan/CISC-121/blob/Assignments/Ben_Feenan_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CISC 121 - Section 001 – Assignment 2**
# *Please copy this notebook to your own drive (File -> Save a copy in Drive) and work from there.*

# %% [markdown]
# ## Part 1
# ### Solve all the 3 problems folloowing the template
#
# 1. **Sum of Two Integers** — <https://leetcode.com/problems/sum-of-two-integers>
# 2. **Convert Date to Binary** — <https://leetcode.com/problems/convert-date-to-binary>
# 3. **Number of 1 Bits** — <https://leetcode.com/problems/number-of-1-bits>

# %% [markdown]
# ## Part 2
# ### Solve 2 of the 3 problems from the followings following the given template
#
# 1. **Reverse Integer** — <https://leetcode.com/problems/reverse-integer>
# 2. **Reverse String** — <https://leetcode.com/problems/reverse-string>
# 3. **Reverse Pairs** — <https://leetcode.com/problems/reverse-pairs>
#
# ### Note: the problems are ordered by difficulty.

# %% [markdown]
# 1. Your Name: Ben Feenan
# 2. Section: 001
# 3. ID:20491383
# 4. Github or Colab link of this notebook:
#
# 5. Links to Chats:

# %% [markdown]
# ---

# %% [markdown]
# #  Problem 1 (DSA)

# %% [markdown]
# ## 1. Understanding & Breakdown
#
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself (Refer to the Syllabus for more details about AI use levels). **Must Provide AI Disclosures**
#
# ###Followings are some ideas of writing this section. You can choose any of these. The goal is to see if you were able to breakdown the problem.
#
# ### **For both Parts (Both DSA & Recursion problems)**
#
# #### _Discuss the problem, using the pillars of Computation: Problem Decomposition, Pattern Recognition, Abstraction, and Algortihmic Thinking. For algorithmic thinking explain the inputs/outputs, constraints, and  draw the flowchart using digital or real pen-paper (For the flow chart only). Insert the image below._
#
#
# ### **For Part 1 (Basic Data Structures and Algorithms Problems)**
#
# - For each, discuss:
#     - How are you dealing with variable datatypes?
#     - Which types of operations are being used and what for?
#     - Which Data collections (structures) are being used, and why? (comapre to others, e.g. lists, dictionaries, sets, tuples, etc.)
#
# - Compare to the other two problems: which ideas generalize? where do they differ?
#     - Use abstraction and pattern recognition to find similarities
#     - Use problem decomposition and algortihmic tinking to identify differnces in term so the the solution
#
#
# ### **For Part 2 (Recursion Problems)**
#
# - For each, discuss:
#     - What are the subproblems the recusrive function should solve?
#     - What the base case and recursive step should do?
#     - How the call stack will organize the recursive calls?
#     - Whether to use head, tail, parameterized, and/or functional recursion, and why?
#     - How are solutions to the subproblems to be combined?
#
# - Compare to the other recursive problems  (similarities/differences)
# - Compare to an iterative solutions (e.g., how would a loop-based version differ?)
# - What needs to be changed for the recursive solution to become head/tail/parameterized/functional recursion
#
#
#
#
#
# **Your effort is more important than the accuracy for this section**
#
# Use the following markdown to provide your answer

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
#
# Visit the **"Solutions"** tab on LeetCode (the provided link above) for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---

# %%
# Your draft code here (does not need to be fully correct)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly. Please provide screenshots from Leetcode_
#
# At this stage, you may:
# - Review solutions using AI tools (e.g., ChatGPT, GitHub Copilot) to add ***comments*** and error handeling, refine, improve, and if there are any, fix errors.
#     -   Tip: Use PROMPT and CoT methods
# - Refactor your draft to ensure accuracy, completeness, follow the Code Review checklist.
#
# ### Don't forget to add comments!
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.
#
# --------------

# %%
# Final working solution
# [AI Disclaimer example: Used ChatGPT with prompt “How to handle recursion base case” only for concept]

# %% [markdown]
# Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Review & Fixes
#
# _What did you improve, optimize from your draft? 2 fixes with your comments._
#
# If there is no imporvments possible, please describe how the final version meets all the Code Review Checklist items
#
# -------

# %%
# Fix 1:

# Draft version (e.g., manual and repetitive logic)

# Fixed version (better structure, easier to understand, and more functional)

# %%
# Fix 2:

# Draft version:


# Fixed version:

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used ChatGPT (Level 4) to help identify an edge case where my draft code failed when the input string started with a closing bracket. I also used ChatGPT to help structure the final loop and mapping dictionary, but verified all logic myself by tracing the code.
#
# 2.  I used ChatGPT to help write the loop. But the code had an indentation error after the `if` block, which caused it to fail. I fixed the spacing and made sure the code runs correctly.
#
# 3. I used opensource code from Github. I found and fixed a logic bug where they used if s[i] == '(' or ')', which always returned True. I corrected it to properly check both conditions.

# %% [markdown]
# ## Your answer:
#
# ------

# %% [markdown]
# ->

# %% [markdown]
# -----------

# %% [markdown]
# #  Repeat this template for Problems 2–5
# You may copy-paste the above section 4 more times or duplicate cells in your notebook environment.
#
# Remember:
# Proper attribution
# No copy-pasting from AI or others
#
# --------

# %% [markdown]
# # Problem 1: Sum of 2 Intergers

# %% [markdown]
# # Part 1.
# I need to get the sum of variables a and b without using + or -. To accomplish this I will add the variables to a list and then get the sum of that list. Variables a and b are both integers, so I will collect the integers into a list because it will allow me to pass the list onto a fucntion that will sum the parts without me using + or -. The contraints are I can't use + or -.

# %% [markdown]
# # Part 2.
# After viewing https://leetcode.com/problems/sum-of-two-integers/solutions/1512422/simple-solution-using-exponents-and-log-faster-then-92 I saw how they stored their variables in a log format. I like this approach of storing the variables in a different format that allows you to add them using a function other than + or - and gives me confidence in my solution.

# %%
class Solution(object):
    def getSum(self, a, b):
        """
        :type a: int
        :type b: int
        :rtype: int
        """
        list = [a,b]
        sum(list)
        return list

# %% [markdown]
# # Part 3.
# ![Screenshot 2025-10-14 at 12.41.21 PM.png](data:image/png;base64,...)

# %%
#Final Working Solution
class Solution(object):
    def getSum(self, a, b):
        """
        :type a: int
        :type b: int
        :rtype: int
        """
        list = [a,b]
        return sum(list)

# %% [markdown]
# # Part 4.

# %%
#Fix 1: I was getting the sum of the list but then returning the original list

#Draft Code
sum(list)
return list

#Fixed Code
list = [a,b]
return sum(list)

# %%
# I did not have a second fix
# The code handles edge cases such as negative numbers by storing the integer as is (with the negative) and allowing the sum function to interpret it properly.

# %% [markdown]
# # Part 5.
# I did not use AI assistance for this question.

# %% [markdown]
# #Problem 2 Convert Date to Binary

# %% [markdown]
# #Part 1.
# I need to take the date given in integers and return the date back in binary form. I can do this by using the bin command to return the numbers in binary. The contraints are that the integer will be 10 digits long and the given variables are all integers.

# %% [markdown]
# #Part 2
# After viewing https://leetcode.com/problems/convert-date-to-binary/solutions/7221141/convert-date-to-binary-easy-optimal-solution-mathematical-approach-c-java-python I see that I can use the slice function to seperate the year. month, and day without having to deal with the dashes, and then I can add the dashes back at the end.

# %%
#Draft Code
class Solution(object):
    def convertDateToBinary(self, date):
        """
        :type date: str
        :rtype: str
        """
        year = bin(date[0:4])
        month = bin(date[5:7])
        day = bin(date[8:10])
        return (year + '-' + month + '-' + day)

# %% [markdown]
# #Part 3![Screenshot 2025-10-15 at 1.55.16 PM.png](data:image/png;base64,...)

# %%
#Correct Code
class Solution(object):
    def convertDateToBinary(self, date):
        """
        :type date: str
        :rtype: str
        """
        year = bin(int(date[0:4]))[2:]
        month = bin(int(date[5:7]))[2:]
        day = bin(int(date[8:10]))[2:]
        return (year + '-' + month + '-' + day)

# %% [markdown]
# #Part 4.

# %%
#Fix 1: I had to cut off the first two digits of the given binary number to return only the number I was looking for.
#Draft code
year = bin(date[0:4])
month = bin(date[5:7])
day = bin(date[8:10])

#Fixed code
year = bin(int(date[0:4]))[2:]
month = bin(int(date[5:7]))[2:]
day = bin(int(date[8:10]))[2:]

# %%
#Fix 2: I had to change the slices of date into integers so that bin is able to use them.
#Draft code
year = bin(date[0:4])
        month = bin(date[5:7])
        day = bin(date[8:10])

#Fixed code
year = bin(int(date[0:4]))[2:]
        month = bin(int(date[5:7]))[2:]
        day = bin(int(date[8:10]))[2:]

# %% [markdown]
# #Part 5.
# 1: I used Chat GPT to help fix a syntax error where my return string would not work. I was missing a + sign after month and kept missing it.
#
# 2: I used Chat GPT to help figure out why I was not able to use bin on my year, month, and day variables. I did not know that bin needs integers to work.

# %% [markdown]
# # Problems 3 Number of 1 Bits

# %% [markdown]
# # Part 1.
# I need to write a function that returns the number of ones in an integer n's binary code. To do this I will get the binary number and create a loop that runs through the binary number and counts the number of ones. The constraints are n should be a positive number and must fit within the 32-bit limit.

# %% [markdown]
# # Part 2.
# After viewing https://leetcode.com/problems/number-of-1-bits/solutions/4341445/beats-100-explained-with-video-interview-solution-visualized-too I see that I should create a seperate variable that I can store the number of counted ones in. Every time I reach a 1 I can store that in my variable to make it easier to keep track of.

# %%
#Draft Code
class Solution(object):
    def hammingWeight(self, n):
        """
        :type n: int
        :rtype: int
        """
        binary_number = bin(n)[2:]

        count = 0

        for x in len(binary_number):
            if x == 0
            skip
            elif x == 1
            count += 1

# %% [markdown]
# #Part 3.
# ![Screenshot 2025-10-15 at 12.40.52 PM.png](data:image/png;base64,...)

# %%
#Working Code
class Solution(object):
    def hammingWeight(self, n):
        """
        :type n: int
        :rtype: int
        """
        binary_number = bin(n)[2:]

        count = 0

        for x in binary_number:
            if x == '1':
                count += 1

        return count

# %% [markdown]
# #Part 4.

# %%
#Fix 1: I removed if x == 0 and skip because it was redundant. The loop will pass over the 0s without it.
#Draft code
for x in len(binary_number):
            if x == 0
            skip
            elif x == 1
            count += 1

#Fixed code
for x in binary_number:
            if x == '1':
                count += 1

# %%
#Fix 2: I did not need to use len(binary_number) because it is already a string and not a single integer.
#Draft code
for x in len(binary_number):

#Fixed code
for x in binary_number:

# %% [markdown]
# #Part 5.
# 1: I used Chat GPT to figure out an error where my loop was not finding 1 in if x == 1. It was becuase I did not have proper quotations to reflect the fact that binary_number is a list and not an integer. I needed to use '1' instead of 1.

# %% [markdown]
# # Problems 4 Reverse String

# %% [markdown]
# # Part 1.
# I have to write a function that reverses a given string. The string must be modified in place. To do this I am going to create a loop that will rotate the letters forward until they are fully reversed. The contraint is the list must be edited in place and must not use too much memory.

# %% [markdown]
# # Part 2.
# After viewing https://leetcode.com/problems/reverse-string/solutions/6635496/master-the-in-place-swap-trick-to-reverse-any-string-efficiently I have learned that I can use two pointers to mark the begining and end of the string then shift it until they are reversed. This will both allow me to solve the problem recursively and properly alter the list in place. I think my original solution would have used to much memory as per the contraints.

# %%
#draft code
class Solution(object):
    def reverseString(self, s):
        """
        :type s: List[str]
        :rtype: None Do not return anything, modify s in-place instead.
        """
        def point_counter(left, right):

            left, right = 0, len(s) -1
            if left >= right:
                return
            s[left], s[right] = s[right], s[left]

            point_counter(left + 1, right - 1)

# %% [markdown]
# #Part 3. ![Screenshot 2025-10-15 at 8.11.16 PM.png](data:image/png;base64,...)

# %%
#Working Code
class Solution(object):
    def reverseString(self, s):
        """
        :type s: List[str]
        :rtype: None Do not return anything, modify s in-place instead.
        """
        def point_counter(left, right):

            if left >= right:
                return
            s[left], s[right] = s[right], s[left]

            point_counter(left + 1, right - 1)
        point_counter(0, len(s)-1)

# %% [markdown]
# # Part 4.

# %%
#Fix 1: I defined my recursive function but never called it so the recursion did not start. My code was not doing anything.
#draft code
s[left], s[right] = s[right], s[left]

            point_counter(left + 1, right - 1)

#fixed code
s[left], s[right] = s[right], s[left]

            point_counter(left + 1, right - 1)
        point_counter(0, len(s)-1)

# %%
#Fix 2: I was trying to set left and right to 0 and -1, but I was doing it on every recursive call, so I created an infinite recursion that never reached the base case.
#draft code
def point_counter(left, right):

            left, right = 0, len(s) -1
            if left >= right:

#fixed code
def point_counter(left, right):

            if left >= right:

# %% [markdown]
# # Part 5.
#
# 1. I used Chat GPT to help me figure out why my recursion was going on infinitely. I thought my reset would happen before the recursion, not during every step. It pointed out that I did not need to reset it at that step becuase my last line calls it the first time at the desired positions.

# %% [markdown]
# # Problems 5 Reverse Integer

# %% [markdown]
# #Part 1.
# I need to take a given integer and reverse it. To do this I am going to create a recursive function that takes the integer, chops the last number and adds it to a new variable. The fucntion will call itslef until there are no digits left in the first integer. The contraints are it has to handle all cases in a 32 bit integer scenario including negative numbers.

# %% [markdown]
# #Part 2.
# After viewing https://leetcode.com/problems/reverse-integer/solutions/7218841/precise-code-with-boundary-conditions I see that I can use absolute value to handle negative and positive cases easily. I must store if it is positive or negative and then I can add the negative sign back later if necessary.

# %%
#Draft code
class Solution(object):
    def reverse(self, x):
        """
        :type x: int
        :rtype: int
        """
        def neg_pos:
        sign = -1 if x < 0 else 1
        n = abs(x)

        def reverse_int(n,rev=0):
            if n == 0:
                return rev
            return reverse_int(n//10, rev *10 + n % 10)

        return sign * reverse_int(n)

# %% [markdown]
# #Part 3.
# ![Screenshot 2025-10-15 at 10.07.17 PM.png](data:image/png;base64,...)

# %%
#Working code
class Solution(object):
    def reverse(self, x):
        """
        :type x: int
        :rtype: int
        """
        min_int, max_int = -2**31, 2**31 - 1
        sign = -1 if x < 0 else 1
        n = abs(x)

        def reverse_int(n,rev=0):
            if n == 0:
                return rev
            return reverse_int(n//10, rev *10 + n % 10)

        r = sign * reverse_int(n)
        return r if min_int < r < max_int else 0

# %% [markdown]
# # Part 4.

# %%
#Fix 1: I needed to include a way to check for the minimum and maximum integers that we are able to include.
#Draft code
def neg_pos:
        sign = -1 if x < 0 else 1
        n = abs(x)

        def reverse_int(n,rev=0):
            if n == 0:
                return rev
            return reverse_int(n//10, rev *10 + n % 10)

        return sign * reverse_int(n)

  #Fixed Code
  min_int, max_int = -2**31, 2**31 - 1
   r = sign * reverse_int(n)
        return r if min_int < r < max_int else 0

# %%
#Fix 2: I did not need to define the neg_pos. It created an error and I never called it because I can just use sign the variable.
#Draft code
def neg_pos:
        sign = -1 if x < 0 else 1
        n = abs(x)

#Fixed code
sign = -1 if x < 0 else 1
      n = abs(x)

# %% [markdown]
# #Part 5.
#
# 1: I used Chat GPT to help order the way I was editing my n variable so that it was able to be called repeatedly.
#
# 2: I used Chat GPT to help me figure out why my minimum and maximum checks were allowing integers outside of the limit to still pass. I needed to check after the final recursion not before.

# %% [markdown]
# ------

# %% [markdown]
# # **The most important part of writing code is not the code itself, but the thinking that leads to it. Thank You 😀**
